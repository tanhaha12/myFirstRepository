# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Loading the data

# %%
main_df = pd.read_csv("/content/drive/MyDrive/credit card csv/creditcard.csv")
main_df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# Pre-processing

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
main_df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
main_df.isnull().values.any()
# Out:
# False

# %% [markdown]
# Statistical distribution

# %%
main_df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
temp_df = main_df.copy()

# %%
main_df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
X = temp_df.drop('Class', axis=1)
Y = temp_df['Class']
X.shape, Y.shape
# Out:
# ((284807, 30), (284807,))

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 30 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
Y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 284807 entries, 0 to 284806
# Series name: Class
# Non-Null Count   Dtype
# --------------   -----
# 284807 non-null  int64
# dtypes: int64(1)
# memory usage: 2.2 MB

# %%
print(temp_df['Amount'].min())
print(temp_df['Amount'].max())
# Out:
# 0.0
# 25691.16

# %% [markdown]
# Normalizing the "Amount" attribute to fit in the scale

# %%
from sklearn.preprocessing import StandardScaler
standard = StandardScaler()

amount = temp_df['Amount'].values
temp_df['Amount'] = standard.fit_transform(amount.reshape(-1,1))

X_scaled = temp_df.drop('Class', axis=1)
y_scaled = temp_df['Class']

X_scaled.shape, y_scaled.shape
# Out:
# ((284807, 30), (284807,))

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# %%
main_df["Label"] = np.where(main_df["Class"] == 1, "Fraud", "No Fraud")

# %%
# Plotting feature vs feature, v1 vs v2
sns.scatterplot(x = "V1", y = "V2", data = main_df, alpha = 0.4, hue = "Label")
# Out:
# <Axes: xlabel='V1', ylabel='V2'>

# %%
# Pair-Plot using the first five attributes
#attributes = main_df[["V1","V2","V3","V4","V5","Label"]]
#sns.pairplot(attributes, hue = "Label", corner = True)

# %%
df_features = main_df.iloc[:,1:29]
df_features.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V19       V20       V21       V22  \
# 0  0.098698  0.363787  0.090794  ...  0.403993  0.251412 -0.018307  0.277838
# 1  0.085102 -0.255425 -0.166974  ... -0.145783 -0.069083 -0.225775 -0.638672
# 2  0.247676 -1.514654  0.207643  ... -2.261857  0.524980  0.247998  0.771679
# 3  0.377436 -1.387024 -0.054952  ... -1.232622 -0.208038 -0.108300  0.005274
# 4 -0.270533  0.817739  0.753074  ...  0.803487  0.408542 -0.009431  0.798278
#
#         V23       V24       V25       V26       V27       V28
# ...

# %%
n_clust = 5
kmeans = KMeans(n_clusters = n_clust)
kmeans.fit(df_features)
labels = kmeans.labels_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.hist(labels)
# Out:
# (array([  3566.,      0., 131992.,      0.,      0.,  97604.,      0.,
#           6138.,      0.,  45507.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
import numpy as np

for clusterNum in range(n_clust):
    nums = np.where(labels == clusterNum)[0]  # Ensure indices are accessed properly
    cluster_df = main_df.iloc[nums]
    means = cluster_df.mean(numeric_only=True)  # Explicitly set numeric_only to True
    percent_fraud = means["Class"]
    print("Cluster {:2d} contains {:.1%} fraud".format(clusterNum, percent_fraud))
# Out:
# Cluster  0 contains 0.3% fraud
# Cluster  1 contains 0.1% fraud
# Cluster  2 contains 0.1% fraud
# Cluster  3 contains 3.3% fraud
# Cluster  4 contains 0.0% fraud

# %% [markdown]
# Applying K means for Datset with 1000 Datapoints

# %%
main_df_1k_fraud = main_df[main_df['Class'] == 1]

# %%
main_df_1k_fraud.shape
# Out:
# (492, 32)

# %%
num_datapoints = 508
main_df_1k_not_fraud = main_df[main_df['Class'] == 0].head(num_datapoints)

# %%
main_df_1k_not_fraud.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V22       V23       V24       V25       V26  \
# 0  0.098698  0.363787  ...  0.277838 -0.110474  0.066928  0.128539 -0.189115
# 1  0.085102 -0.255425  ... -0.638672  0.101288 -0.339846  0.167170  0.125895
# 2  0.247676 -1.514654  ...  0.771679  0.909412 -0.689281 -0.327642 -0.139097
# 3  0.377436 -1.387024  ...  0.005274 -0.190321 -1.175575  0.647376 -0.221929
# 4 -0.270533  0.817739  ...  0.798278 -0.137458  0.141267 -0.206010  0.502292
#
# ...

# %%
main_df_1k = pd.concat([main_df_1k_fraud, main_df_1k_not_fraud])
main_df_1k.shape
# Out:
# (1000, 32)

# %%
df_features_1k = main_df_1k.iloc[:,1:29]
df_features_1k.head()
# Out:
#             V1        V2        V3        V4        V5        V6        V7  \
# 541  -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387
# 623  -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
# 4920 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788  0.562320
# 6108 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536 -3.496197
# 6329  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746  1.713445
#
#             V8        V9       V10  ...       V19       V20       V21  \
# 541   1.391657 -2.770089 -2.772272  ...  0.416956  0.126911  0.517232
# 623  -0.067794 -0.270953 -0.838587  ...  0.283345  2.102339  0.661696
# 4920 -0.399147 -0.238253 -1.525412  ... -1.334441 -0.430022 -0.294166
# 6108 -0.248778 -0.247768 -4.801637  ...  0.308334 -0.171608  0.573574
# 6329 -0.496358 -1.282858 -2.447469  ... -2.721853  0.009061 -0.379068
#
#            V22       V23       V24       V25       V26       V27       V28
# ...

# %%
n_clust = 5
kmeans = KMeans(n_clusters = n_clust)
kmeans.fit(df_features_1k)
labels = kmeans.labels_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.hist(labels)
# Out:
# (array([ 66.,   0., 616.,   0.,   0.,  41.,   0., 271.,   0.,   6.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
for clusterNum in range(n_clust):
  nums = np.where(labels == clusterNum)
  cluster_df = main_df_1k.iloc[nums]
  means = cluster_df.mean(numeric_only=True)
  percent_fraud = means["Class"]
  print("Cluster {:2d} contains {:.1%} fraud".format(clusterNum, percent_fraud))
# Out:
# Cluster  0 contains 100.0% fraud
# Cluster  1 contains 17.5% fraud
# Cluster  2 contains 100.0% fraud
# Cluster  3 contains 100.0% fraud
# Cluster  4 contains 100.0% fraud

# %% [markdown]
# Applying K means on 10k Datapoints

# %%
num_datapoints = 9508
main_df_10k_not_fraud = main_df[main_df['Class'] == 0].head(num_datapoints)

# %%
main_df_10k = pd.concat([main_df_1k_fraud, main_df_10k_not_fraud])
main_df_10k.shape
# Out:
# (10000, 32)

# %%
df_features_10k = main_df_10k.iloc[:,1:29]
df_features_10k.head()
# Out:
#             V1        V2        V3        V4        V5        V6        V7  \
# 541  -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387
# 623  -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
# 4920 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788  0.562320
# 6108 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536 -3.496197
# 6329  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746  1.713445
#
#             V8        V9       V10  ...       V19       V20       V21  \
# 541   1.391657 -2.770089 -2.772272  ...  0.416956  0.126911  0.517232
# 623  -0.067794 -0.270953 -0.838587  ...  0.283345  2.102339  0.661696
# 4920 -0.399147 -0.238253 -1.525412  ... -1.334441 -0.430022 -0.294166
# 6108 -0.248778 -0.247768 -4.801637  ...  0.308334 -0.171608  0.573574
# 6329 -0.496358 -1.282858 -2.447469  ... -2.721853  0.009061 -0.379068
#
#            V22       V23       V24       V25       V26       V27       V28
# ...

# %%
n_clust = 5
kmeans = KMeans(n_clusters = n_clust)
kmeans.fit(df_features_10k)
labels = kmeans.labels_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.hist(labels)
# Out:
# (array([ 276.,    0.,   97.,    0.,    0.,   16.,    0., 4050.,    0.,
#         5561.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
for clusterNum in range(n_clust):
  nums = np.where(labels == clusterNum)
  cluster_df = main_df_10k.iloc[nums]
  means = cluster_df.mean(numeric_only=True)
  percent_fraud = means["Class"]
  print("Cluster {:2d} contains {:.1%} fraud".format(clusterNum, percent_fraud))
# Out:
# Cluster  0 contains 100.0% fraud
# Cluster  1 contains 100.0% fraud
# Cluster  2 contains 100.0% fraud
# Cluster  3 contains 2.2% fraud
# Cluster  4 contains 0.3% fraud

# %%
for clusterNum in range(n_clust):
    nums = np.where(labels == clusterNum)
    num_datapoints = len(nums[0])
    print("Cluster {:2d} contains {} data points".format(clusterNum, num_datapoints))
# Out:
# Cluster  0 contains 276 data points
# Cluster  1 contains 97 data points
# Cluster  2 contains 16 data points
# Cluster  3 contains 4050 data points
# Cluster  4 contains 5561 data points
